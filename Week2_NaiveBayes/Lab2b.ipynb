# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import accuracy_score

# Đọc dữ liệu
df = pd.read_csv("../Week1/multinomial_nb_orders.csv")

target_feature = "cuisine"
X = df.drop(columns=[target_feature])
y = df[target_feature]

# Mã hóa categorical thành số nguyên
encoders = {}
for col in X.columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    encoders[col] = le  # lưu lại nếu cần giải mã ngược

y_le = LabelEncoder()
y = y_le.fit_transform(y)

# Tách train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Dùng Naïve Bayes cho dữ liệu categorical
model = CategoricalNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.47555555555555556

# %%
print()
# Out:
# [8 1 1 ... 7 8 4]
